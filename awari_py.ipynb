# %% [markdown]
# <a href="https://colab.research.google.com/github/kseishi/python_awari/blob/main/awari_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Qual o resultado do comando abaixo?

# %%
salario = 2000

# %%
if (salario > 500):
  salario_novo=salario+500
  print('salario com ajuste' '=',salario_novo)
# Out:
# salario com ajuste= 2500

# %% [markdown]
# resposta : alternativa c

# %% [markdown]
# 2) Qual o resultado do comando abaixo?

# %%
def soma(a,b):
  return a+5, b+2
resultado = soma (5,6)
print(resultado)
# Out:
# (10, 8)

# %% [markdown]
# resposta : alternatica d

# %% [markdown]
# 3) Qual o resultado do comando abaixo?

# %%
lista = [12,5,2,1,9,55]
print(lista[6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-7241b78d6146> in <cell line: 2>()
#       1 lista = [12,5,2,1,9,55]
# ----> 2 print(lista[6])
#
# IndexError: list index out of range

# %% [markdown]
# resposta : alternativa a

# %% [markdown]
# 4) Qual o tipo da variável var_exemplo?

# %%
var_exemplo = 3.87
print(type(var_exemplo))
# Out:
# <class 'float'>

# %% [markdown]
# resposta: alternativa d

# %% [markdown]
# 5) Qual o último número exibido na saída do FOR?

# %%
for numero in range(1,10):
  print(numero)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %% [markdown]
# resposta: alternatica b

# %% [markdown]
# 6) Qual o resultado do print da variável dia_semana?

# %%
dia_semana = ('segunda', 'terça', 'quarta', 'quinta', 'sexta')
dia_semana.append('sabado')
print(dia_semana)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-06a841943443> in <cell line: 2>()
#       1 dia_semana = ('segunda', 'terça', 'quarta', 'quinta', 'sexta')
# ----> 2 dia_semana.append('sabado')
#       3 print(dia_semana)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# resposta: alternativa d

# %% [markdown]
# 7) Qual sintaxe de criação de uma classe está correta?

# %%
class Carro:
  def __init__(self, cor, marca, categoria,  ano=2022):
    self.cor = cor
    self.marca = marca
    self.categoria = categoria
    self.ano = ano

# %% [markdown]
# resposta: alternativa d

# %% [markdown]
# 8) Qual biblioteca é destinada para gerar gráficos
# resposta: alternativa a

# %% [markdown]
# 9) Qual o erro na sintaxe abaixo?

# %%
def eleva_ao_quadrado(n):
  raiz_quadrada = n **2
  return raiz_quadrada
print(eleva_ao_quadrado(5))
# Out:
# 25

# %% [markdown]
# resposta: alternativa c

# %% [markdown]
# 10) Qual a principal características da biblioteca Pandas?
# alternativa: a

# %% [markdown]
# 11) Qual a saída do comando abaixo?

# %%
num_1 = 2
num_2 = 10
multiplica = num_1 * num_2

if multiplica > 50:
  print('o numero é maior')
elif multiplica ==15:
  print('o numero é = 15')
else:
  print('nenhuma condicao atendida')
# Out:
# nenhuma condicao atendida

# %% [markdown]
# resposta : alternativa a

# %% [markdown]
# 12) O que é Code Clean?
# alternativa a

# %% [markdown]
# 13) A qual grupo de tipos de operador o operador += faz parte?
# alternativa: a

# %% [markdown]
# 14) Qual destes objetos é constituído por elementos de chave e valor?
# alternativa: d

# %% [markdown]
# 15) O que acontecerá ao executar esse comando While?

# %%
contador = 0
while contador < 3:
  print('contador é igual', contador)
  contador += 1
  contador = contador = 0
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# contador é igual 0
# ...

# %% [markdown]
# resposta: alternativa c
